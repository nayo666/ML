# %% [markdown]
# # Kmeans aplicación

# %%
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
img = imread("01.jpg")
plt.figure(figsize=(10, 10))
plt.imshow(img)
plt.show()

# %%
s = img.shape
X = img.reshape(s[0] * s[1], s[2])
print(X.shape)
# Out:
# (12000000, 3)

# %% [markdown]
# # Separar el objeto del fondo

# %%
K = 2
km = KMeans(K)
X_km = km.fit_predict(X)

# %%
Y = X_km.reshape(s[0],s[1])
plt.figure(figsize=(10, 10))
plt.imshow((Y.astype("uint8")))
plt.show()

# %% [markdown]
# # Aplicar K-means a los puntos de objetos

# %%
coin_points = np.where(Y>0)
coin_points = np.concatenate([coin_points], axis=1).transpose()
coin_points.shape
# Out:
# (2049005, 2)

# %%
coin_points
# Out:
# array([[ 256,  944],
#        [ 256,  945],
#        [ 256,  946],
#        ...,
#        [2575, 2309],
#        [2575, 2310],
#        [2576, 2297]])

# %%
K = 3
km2 = KMeans(K)
km2.fit(coin_points)
coins = km2.cluster_centers_
coins
# Out:
# array([[2024.19015598, 1998.28139198],
#        [ 876.35726958, 2831.18249109],
#        [ 710.26845509, 1277.48803531]])

# %%
plt.imshow(img)
plt.scatter(coins[:, 1], coins[:, 0], c="r", marker='x', s=100)
plt.show()

# %% [markdown]
# # Más ejemplos

# %%
img2 = imread("02.jpg")
s = img2.shape
X = img2.reshape(s[0] * s[1], s[2])
K = 3
km = KMeans(K)
pred = km.fit_predict(X).reshape(s[0], s[1])
plt.imshow(pred)
plt.show()

# %%
monedas = 3
coin_points = np.where(pred>0)
coin_points = np.concatenate([coin_points], axis=1).transpose()
km2 = KMeans(monedas)
km2.fit(coin_points)
coins = km2.cluster_centers_
plt.imshow(img2)
plt.scatter(coins[:, 1], coins[:, 0], c="r", marker='x', s=100)
plt.show()

# %%
img2 = imread("03.jpg")
s = img2.shape
X = img2.reshape(s[0] * s[1], s[2])
K = 2
km = KMeans(K)
pred = km.fit_predict(X).reshape(s[0], s[1])
plt.imshow(pred)
plt.show()

# %%
monedas = 3
coin_points = np.where(pred>0)
coin_points = np.concatenate([coin_points], axis=1).transpose()
km2 = KMeans(monedas)
km2.fit(coin_points)
coins = km2.cluster_centers_
plt.imshow(img2)
plt.scatter(coins[:, 1], coins[:, 0], c="r", marker='x', s=100)
plt.show()

# %%
img2 = imread("04.jpg")
s = img2.shape
X = img2.reshape(s[0] * s[1], s[2])
K = 3
km = KMeans(K)
pred = km.fit_predict(X).reshape(s[0], s[1])
plt.imshow(pred)
plt.show()

# %%
monedas = 3
coin_points = np.where(pred>0)
coin_points = np.concatenate([coin_points], axis=1).transpose()
km2 = KMeans(monedas)
km2.fit(coin_points)
coins = km2.cluster_centers_
plt.imshow(img2)
plt.scatter(coins[:, 1], coins[:, 0], c="r", marker='x', s=100)
plt.show()
